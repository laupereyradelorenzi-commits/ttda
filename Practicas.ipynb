# %%
import pandas as pd

# %%
df = pd.read_csv("who.csv")
df.isna().sum()

# df = df[["Country",df.columns[-2]]]
# print(df[:5])
# Out:
# Country                            0
# CountryID                          0
# Continent                          0
# Adolescent fertility rate (%)     25
# Adult literacy rate (%)           71
#                                   ..
# Under_five_mortality_from_IHME    32
# Under_five_mortality_rate         21
# Urban_population                  14
# Urban_population_growth           14
# Urban_population_pct_of_total     14
# Length: 358, dtype: int64

# %%
# Como ya sabéis através de la API se puede obtener una descripción más detallada de las posibilidades de cada método de Python, y en especial
# de los métodos de Pandas.
# Para cargar un fichero de tamaño elevado es recomendable cargar aquellos atributos que nos interesen desde un principio usando el argumento: usecols
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html
df = pd.read_csv("who.csv", usecols=["Country","Urban_population_growth"])
print(df[:5])
# Out:
#        Country  Urban_population_growth
# 0  Afghanistan                     5.44
# 1      Albania                     2.21
# 2      Algeria                     2.61
# 3      Andorra                      NaN
# 4       Angola                     4.14

# %%
# ¿Qué valor corresponde a un NA del dataframe?
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isna.html
df.isna().sum()
# Out:
# Country                     0
# Urban_population_growth    14
# dtype: int64

# %%
#¿Qué columnas tienen datos sin valor: NaN, NaT, None?
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.any.html

print(df.columns[df.isna().any()])

# Equivale a preguntar si ¿existe algún valor positivo dentro de esas series?
print("-"*30)
print(df.any())isna()
# Out:
#   Cell In[8], line 8
#     print(df.any())isna()
#                    ^
# SyntaxError: invalid syntax

# %%
#No dudéis en ejecutar "partes" (dividamos la instrucción para comprenderla)
print(df.isna()[:5])
# Out:
#    Country  Urban_population_growth
# 0    False                    False
# 1    False                    False
# 2    False                    False
# 3    False                     True
# 4    False                    False

# %%
#¿Cuántas muestras son correctas?
df.notna().sum()
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.notna.html
# y de cuantas muestras?
# Out:
# Country                    202
# Urban_population_growth    188
# dtype: int64

# %%
df.notnull().sum() #ambas funcionas son equivalentes en Pandas, no en numpy
# Out:
# Country                    202
# Urban_population_growth    188
# dtype: int64

# %%
#Tratando la ausencia de datos. reemplazo por 0, por la media, elimino la fila, y si la columna tuviese muchos NaN puedo eliminar la col

# %%
#La manera más optima de remplazar estos valores es con la función: fillna
print(df.fillna(0)[:5]) #reemplazo por 0
# Out:
#        Country  Urban_population_growth
# 0  Afghanistan                     5.44
# 1      Albania                     2.21
# 2      Algeria                     2.61
# 3      Andorra                     0.00
# 4       Angola                     4.14

# %%
import numpy as np

np.random.seed(20)

#Creamos un dataframe
df = pd.DataFrame(np.random.randn(5, 3),
                     index=['a', 'b', 'c', 'd', 'e'],
                     columns=['one', 'two', 'three'])
print(df)
# Out:
#         one       two     three
# a  0.883893  0.195865  0.357537
# b -2.343262 -1.084833  0.559696
# c  0.939469 -0.978481  0.503097
# d  0.406414  0.323461 -0.493411
# e -0.792017 -0.842368 -1.279503

# %%
#Creamos valores NaN para testear
df.two[df.two<0]=np.nan
print(df)
# Out:
#         one       two     three
# a  0.883893  0.195865  0.357537
# b -2.343262       NaN  0.559696
# c  0.939469       NaN  0.503097
# d  0.406414  0.323461 -0.493411
# e -0.792017       NaN -1.279503
# C:\Users\Nico\AppData\Local\Temp\ipykernel_12432\3879635901.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.two[df.two<0]=np.nan

# %%
print(df)
print("-"*33)
print(df.fillna(df.mean())) #reemplazo por la media
# Out:
#         one       two     three
# a  0.883893  0.195865  0.357537
# b -2.343262       NaN  0.559696
# c  0.939469       NaN  0.503097
# d  0.406414  0.323461 -0.493411
# e -0.792017       NaN -1.279503
# ---------------------------------
#         one       two     three
# a  0.883893  0.195865  0.357537
# b -2.343262  0.259663  0.559696
# c  0.939469  0.259663  0.503097
# d  0.406414  0.323461 -0.493411
# e -0.792017  0.259663 -1.279503

# %%
#Con un valor en concreto del propio dataframe
print(df.fillna("HOLA"))
print("-"*33)
print(df.fillna(df.loc["a", ["one"]].values[0]))
# Out:
#         one       two     three
# a  0.883893  0.195865  0.357537
# b -2.343262      HOLA  0.559696
# c  0.939469      HOLA  0.503097
# d  0.406414  0.323461 -0.493411
# e -0.792017      HOLA -1.279503
# ---------------------------------
#         one       two     three
# a  0.883893  0.195865  0.357537
# b -2.343262  0.883893  0.559696
# c  0.939469  0.883893  0.503097
# d  0.406414  0.323461 -0.493411
# e -0.792017  0.883893 -1.279503

# %%
#Podemos rellenar con datos interpolados

# %%
print(df)
print("-"*35)
print(df.interpolate())
# Out:
#         one       two     three
# a  0.883893  0.195865  0.357537
# b -2.343262       NaN  0.559696
# c  0.939469       NaN  0.503097
# d  0.406414  0.323461 -0.493411
# e -0.792017       NaN -1.279503
# -----------------------------------
#         one       two     three
# a  0.883893  0.195865  0.357537
# b -2.343262  0.238397  0.559696
# c  0.939469  0.280929  0.503097
# d  0.406414  0.323461 -0.493411
# e -0.792017  0.323461 -1.279503

# %%
print(df.interpolate(axis=1)) # Tomemos como referencia el valor NA de (b,"two")
print("--"*35)
print(df.mean(axis=1).b)
# Out:
#         one       two     three
# a  0.883893  0.195865  0.357537
# b -2.343262 -0.891783  0.559696
# c  0.939469  0.721283  0.503097
# d  0.406414  0.323461 -0.493411
# e -0.792017 -1.035760 -1.279503
# ----------------------------------------------------------------------
# -0.8917828081181468

# %%
# Para usar otro tipo de interpolaciones es recomendable tener un índice numérico por cuestiones de frecuencia en el método de interpolación
df.index = range(len(df))
print(df.two.interpolate(method="pad"))
# Out:
# 0    0.195865
# 1    0.195865
# 2    0.195865
# 3    0.323461
# 4    0.323461
# Name: two, dtype: float64
# C:\Users\Nico\AppData\Local\Temp\ipykernel_12432\2480900594.py:3: FutureWarning: Series.interpolate with method=pad is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(df.two.interpolate(method="pad"))

# %%
print(df.two.interpolate(method="nearest"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\ttda\.venv\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'scipy'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print(df.two.interpolate(method="nearest"))
#
# File ~\ttda\.venv\Lib\site-packages\pandas\core\generic.py:8526, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    8524 else:
#    8525     index = missing.get_interp_index(method, obj.index)
# -> 8526     new_data = obj._mgr.interpolate(
#    8527         method=method,
#    8528         index=index,
#    8529         limit=limit,
#    8530         limit_direction=limit_direction,
#    8531         limit_area=limit_area,
#    8532         inplace=inplace,
#    8533         downcast=downcast,
#    8534         **kwargs,
#    8535     )
#    8537 result = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    8538 if should_transpose:
#
# File ~\ttda\.venv\Lib\site-packages\pandas\core\internals\base.py:291, in DataManager.interpolate(self, inplace, **kwargs)
#     290 def interpolate(self, inplace: bool, **kwargs) -> Self:
# --> 291     return self.apply_with_block(
#     292         "interpolate",
#     293         inplace=inplace,
#     294         **kwargs,
#     295         using_cow=using_copy_on_write(),
#     296         already_warned=_AlreadyWarned(),
#     297     )
#
# File ~\ttda\.venv\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\ttda\.venv\Lib\site-packages\pandas\core\internals\blocks.py:1863, in Block.interpolate(self, method, index, inplace, limit, limit_direction, limit_area, downcast, using_cow, already_warned, **kwargs)
#    1860 copy, refs = self._get_refs_and_copy(using_cow, inplace)
#    1862 # Dispatch to the EA method.
# -> 1863 new_values = self.array_values.interpolate(
#    1864     method=method,
#    1865     axis=self.ndim - 1,
#    1866     index=index,
#    1867     limit=limit,
#    1868     limit_direction=limit_direction,
#    1869     limit_area=limit_area,
#    1870     copy=copy,
#    1871     **kwargs,
#    1872 )
#    1873 data = extract_array(new_values, extract_numpy=True)
#    1875 if (
#    1876     not copy
#    1877     and warn_copy_on_write()
#    1878     and already_warned is not None
#    1879     and not already_warned.warned_already
#    1880 ):
#
# File ~\ttda\.venv\Lib\site-packages\pandas\core\arrays\numpy_.py:310, in NumpyExtensionArray.interpolate(self, method, axis, index, limit, limit_direction, limit_area, copy, **kwargs)
#     307     out_data = self._ndarray.copy()
#     309 # TODO: assert we have floating dtype?
# --> 310 missing.interpolate_2d_inplace(
#     311     out_data,
#     312     method=method,
#     313     axis=axis,
#     314     index=index,
#     315     limit=limit,
#     316     limit_direction=limit_direction,
#     317     limit_area=limit_area,
#     318     **kwargs,
#     319 )
#     320 if not copy:
#     321     return self
#
# File ~\ttda\.venv\Lib\site-packages\pandas\core\missing.py:410, in interpolate_2d_inplace(data, index, axis, method, limit, limit_direction, limit_area, fill_value, mask, **kwargs)
#     391     _interpolate_1d(
#     392         indices=indices,
#     393         yvalues=yvalues,
#    (...)    401         **kwargs,
#     402     )
#     404 # error: Argument 1 to "apply_along_axis" has incompatible type
#     405 # "Callable[[ndarray[Any, Any]], None]"; expected "Callable[...,
#     406 # Union[_SupportsArray[dtype[<nothing>]], Sequence[_SupportsArray
#     407 # [dtype[<nothing>]]], Sequence[Sequence[_SupportsArray[dtype[<nothing>]]]],
#     408 # Sequence[Sequence[Sequence[_SupportsArray[dtype[<nothing>]]]]],
#     409 # Sequence[Sequence[Sequence[Sequence[_SupportsArray[dtype[<nothing>]]]]]]]]"
# --> 410 np.apply_along_axis(func, axis, data)
#
# File ~\ttda\.venv\Lib\site-packages\numpy\lib\_shape_base_impl.py:393, in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     389 except StopIteration:
#     390     raise ValueError(
#     391         'Cannot apply_along_axis when any iteration dimensions are 0'
#     392     ) from None
# --> 393 res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     395 # build a buffer for storing evaluations of func1d.
#     396 # remove the requested axis, and add the new ones on the end.
#     397 # laid out so that each write is contiguous.
#     398 # for a tuple index inds, buff[inds] = func1d(inarr_view[inds])
#     399 if not isinstance(res, matrix):
#
# File ~\ttda\.venv\Lib\site-packages\pandas\core\missing.py:391, in interpolate_2d_inplace.<locals>.func(yvalues)
#     388 def func(yvalues: np.ndarray) -> None:
#     389     # process 1-d slices in the axis direction
# --> 391     _interpolate_1d(
#     392         indices=indices,
#     393         yvalues=yvalues,
#     394         method=method,
#     395         limit=limit,
#     396         limit_direction=limit_direction,
#     397         limit_area=limit_area_validated,
#     398         fill_value=fill_value,
#     399         bounds_error=False,
#     400         mask=mask,
#     401         **kwargs,
#     402     )
#
# File ~\ttda\.venv\Lib\site-packages\pandas\core\missing.py:528, in _interpolate_1d(indices, yvalues, method, limit, limit_direction, limit_area, fill_value, bounds_error, order, mask, **kwargs)
#     524     yvalues[invalid] = np.interp(
#     525         indices[invalid], indices[valid][indexer], yvalues[valid][indexer]
#     526     )
#     527 else:
# --> 528     yvalues[invalid] = _interpolate_scipy_wrapper(
#     529         indices[valid],
#     530         yvalues[valid],
#     531         indices[invalid],
#     532         method=method,
#     533         fill_value=fill_value,
#     534         bounds_error=bounds_error,
#     535         order=order,
#     536         **kwargs,
#     537     )
#     539 if mask is not None:
#     540     mask[:] = False
#
# File ~\ttda\.venv\Lib\site-packages\pandas\core\missing.py:565, in _interpolate_scipy_wrapper(x, y, new_x, method, fill_value, bounds_error, order, **kwargs)
#     559 """
#     560 Passed off to scipy.interpolate.interp1d. method is scipy's kind.
#     561 Returns an array interpolated at new_x.  Add any new methods to
#     562 the list in _clean_interp_method.
#     563 """
#     564 extra = f"{method} interpolation requires SciPy."
# --> 565 import_optional_dependency("scipy", extra=extra)
#     566 from scipy import interpolate
#     568 new_x = np.asarray(new_x)
#
# File ~\ttda\.venv\Lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'scipy'. nearest interpolation requires SciPy. Use pip or conda to install scipy.

# %%
print("Valores interpolados:" + str(df.two.interpolate().count()-df.two.count()))
# Out:
# Valores interpolados:3

# %%
#Eliminación de valores NA

# %%
print(df)
print("-"*35)
print(df.dropna()) #elimina cualquier fila con NaN

# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html
# Out:
#         one       two     three
# 0  0.883893  0.195865  0.357537
# 1 -2.343262       NaN  0.559696
# 2  0.939469       NaN  0.503097
# 3  0.406414  0.323461 -0.493411
# 4 -0.792017       NaN -1.279503
# -----------------------------------
#         one       two     three
# 0  0.883893  0.195865  0.357537
# 3  0.406414  0.323461 -0.493411

# %%
#O bien, podemos borrar cambiando el eje AXIS=0 o 1
df.dropna(axis=1) #elimina columnas
# Out:
#         one     three
# 0  0.883893  0.357537
# 1 -2.343262  0.559696
# 2  0.939469  0.503097
# 3  0.406414 -0.493411
# 4 -0.792017 -1.279503

# %%
#Ejercicios

# %%
df = pd.read_csv("who.csv")
df.isna()
# Out:
#      Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 0      False      False      False                          False
# 1      False      False      False                          False
# 2      False      False      False                          False
# 3      False      False      False                           True
# 4      False      False      False                          False
# ..       ...        ...        ...                            ...
# 197    False      False      False                          False
# 198    False      False      False                           True
# 199    False      False      False                          False
# 200    False      False      False                          False
# 201    False      False      False                          False
#
#      Adult literacy rate (%)  \
# 0                      False
# 1                      False
# 2                      False
# 3                       True
# 4                      False
# ..                       ...
# 197                    False
# 198                     True
# 199                    False
# 200                    False
# 201                    False
#
#      Gross national income per capita (PPP international $)  \
# 0                                                 True
# 1                                                False
# 2                                                False
# 3                                                 True
# 4                                                False
# ..                                                 ...
# 197                                              False
# 198                                               True
# 199                                              False
# 200                                              False
# 201                                               True
#
#      Net primary school enrolment ratio female (%)  \
# 0                                             True
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ..                                             ...
# 197                                          False
# 198                                           True
# 199                                          False
# 200                                          False
# 201                                          False
#
#      Net primary school enrolment ratio male (%)  \
# 0                                           True
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ..                                           ...
# 197                                        False
# 198                                         True
# 199                                        False
# 200                                        False
# 201                                        False
#
#      Population (in thousands) total  Population annual growth rate (%)  ...  \
# 0                              False                              False  ...
# 1                              False                              False  ...
# 2                              False                              False  ...
# 3                              False                              False  ...
# 4                              False                              False  ...
# ..                               ...                                ...  ...
# 197                            False                              False  ...
# 198                             True                               True  ...
# 199                            False                              False  ...
# 200                            False                              False  ...
# 201                            False                              False  ...
#
#      Total_CO2_emissions  Total_income  Total_reserves  \
# 0                  False          True            True
# 1                  False         False           False
# 2                  False         False           False
# 3                   True          True            True
# 4                  False         False           False
# ..                   ...           ...             ...
# 197                False         False           False
# 198                False         False            True
# 199                False         False           False
# 200                False         False           False
# 201                False         False           False
#
#      Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 0                                True                          False
# 1                               False                          False
# 2                               False                          False
# 3                                True                           True
# 4                               False                          False
# ..                                ...                            ...
# 197                             False                          False
# 198                              True                          False
# 199                             False                          False
# 200                             False                          False
# 201                             False                          False
#
#      Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 0                             False                      False
# 1                             False                      False
# 2                             False                      False
# 3                              True                       True
# 4                             False                      False
# ..                              ...                        ...
# 197                           False                      False
# 198                           False                      False
# 199                           False                      False
# 200                           False                      False
# 201                           False                      False
#
#      Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 0               False                    False                          False
# 1               False                    False                          False
# 2               False                    False                          False
# 3                True                     True                           True
# 4               False                    False                          False
# ..                ...                      ...                            ...
# 197             False                    False                          False
# 198             False                    False                          False
# 199             False                    False                          False
# 200             False                    False                          False
# 201             False                    False                          False
#
# [202 rows x 358 columns]

# %%
df.isna().sum()
# Out:
# Country                            0
# CountryID                          0
# Continent                          0
# Adolescent fertility rate (%)     25
# Adult literacy rate (%)           71
#                                   ..
# Under_five_mortality_from_IHME    32
# Under_five_mortality_rate         21
# Urban_population                  14
# Urban_population_growth           14
# Urban_population_pct_of_total     14
# Length: 358, dtype: int64

# %%
df.isna('Country')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.isna('Country')
#
# TypeError: DataFrame.isna() takes 1 positional argument but 2 were given

# %%
df1 = pd.read_csv("who.csv", usecols=["Country"])
df1.isna()
# Out:
#      Country
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ..       ...
# 197    False
# 198    False
# 199    False
# 200    False
# 201    False
#
# [202 rows x 1 columns]
